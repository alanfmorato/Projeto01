# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import sql

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_obesos = df[(df.Age > 50)]
df_obesos
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 719            5       97             76             27        0  35.6
# 734            2      105             75              0        0  23.3
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# ...

# %%
def Obesidade(BMI):
    if BMI > 30:
        return "1"
    elif BMI < 30:
        return "0"

df_obesos['Obesidade'] = df_obesos['BMI'].map(Obesidade)
display(df_obesos.head())
# Out:
# C:\Users\DNC-PC-138\AppData\Local\Temp\ipykernel_4016\3962507224.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obesos['Obesidade'] = df_obesos['BMI'].map(Obesidade)
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome Obesidade
# 8                      0.158   53        1         1
# ...

# %%
df_obesos = df[(df_obesos.Obesidade == 1)]
df_obesos
# Out:
# C:\Users\DNC-PC-138\AppData\Local\Temp\ipykernel_4016\1405554241.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_obesos = df[(df_obesos.Obesidade == 1)]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In [104], line 1
# ----> 1 df_obesos = df[(df_obesos.Obesidade == 1)]
#       2 df_obesos
#
# File c:\Users\DNC-PC-138\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3796, in DataFrame.__getitem__(self, key)
#    3794 # Do we have a (boolean) 1d indexer?
#    3795 if com.is_bool_indexer(key):
# -> 3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#    3800 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...
