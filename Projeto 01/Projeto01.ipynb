# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import sql

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df = df[(df.Age > 50)]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 719            5       97             76             27        0  35.6
# 734            2      105             75              0        0  23.3
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# ...

# %%
def result(BMI):
    if BMI > 30:
        return 1
    elif BMI < 30:
        return 0

df['resultado'] = df['BMI'].map(result)
df.head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
#
#     DiabetesPedigreeFunction  Age  Outcome  resultado
# 8                      0.158   53        1          1
# 9                      0.232   54        1          0
# 12                     1.441   57        0          0
# 13                     0.398   59        1          1
# 14                     0.587   51        1          0

# %%
df = df[(df.resultado == 1)]
df.head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8             2      197             70             45      543  30.5
# 13            1      189             60             23      846  30.1
# 24           11      143             94             33      146  36.6
# 30            5      109             75             26        0  36.0
# 39            4      111             72             47      207  37.1
#
#     DiabetesPedigreeFunction  Age  Outcome  resultado
# 8                      0.158   53        1          1
# 13                     0.398   59        1          1
# 24                     0.254   51        1          1
# 30                     0.546   60        0          1
# 39                     1.390   56        1          1

# %%
df.to_csv("tratado")

# %%
df.shape
# Out:
# (43, 10)
